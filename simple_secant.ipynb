# %%
import matplotlib.pyplot as plt
def f(y_hat):
    return (y_hat) ** 2
x = []
y = []
for i in range(9):
    x.append(i)
    y.append(f(i))
for i in range(8, 1, -1):
    plt.plot(x,y)
    plt.plot([x[2], x[i]],[y[2], y[i]])
    plt.show()
